# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
df = pd.read_csv("a8zF9nMlTgC4M2HxhhLS_tips.csv")
df.dropna(inplace = True)

# %%
df.columns = ["facture_totale", "pourboire","sexe","fumeur","jour","temps","taille_groupe"]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.head()
# Out:
#    facture_totale  pourboire    sexe fumeur jour   temps  taille_groupe
# 0           16.99       1.01  Female     No  Sun  Dinner              2
# 1           10.34       1.66    Male     No  Sun  Dinner              3
# 2           21.01       3.50    Male     No  Sun  Dinner              3
# 3           23.68       3.31    Male     No  Sun  Dinner              2
# 4           24.59       3.61  Female     No  Sun  Dinner              4

# %%
sns.catplot(data = df, x="sexe", y= "pourboire", hue="fumeur", col="temps")

# %%
sns.catplot(data = df, x="sexe", y= "pourboire", hue="fumeur", col="temps", kind="box")

# %%
sns.catplot(data = df, x = "pourboire", y= "jour", hue="temps" )

# %% [markdown]
# les hommes sont les plus nombreux à frequenter les restaurants et laissent majoritairement des pourboires élevés pendant les heures du diner
# il y a une grande afluance les week end (samedis et dimanches) aux heures du diners ce qui favorise plus de pourboire pour les serveurs.
# pendant les jours ouvrables comme le mardis, les restaurants sont plus frequetés aux heures du déjeuner
#
# en resumer
# les gerants des restaurants doivent faire un planing de sorte que chaques serveurs puissent etre de service un jour les week ainsi que les mardi

# %%
sns.catplot(data = df, x="pourboire", y= "facture_totale", hue="temps", col="jour")

# %% [markdown]
# Plus la facture total est elévé plus pour le pourboir est éléve

# %%
sns.catplot(data = df, x="taille_groupe", y= "pourboire", hue="sexe", col="temps")
